# %%
#pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup
import math

# %%
sr = pd.read_csv("/Users/Jeanne/Documents/personal/Auction Results/soldresults10yr.csv")
ped = pd.read_csv("/Users/Jeanne/Documents/personal/Auction Results/pedigree.csv")

# %%
ped.shape
# Out:
# (16745, 17)

# %%
dt = ped

# %%
master = list(sr['Damf'])
master.extend(list(sr['Siref']))
#master.extend(list(sr['DS']))
#hrnlist = list(hrn['Horse'])

#df = ped
#headers = ['Date', 'Horse', 'Fin', 'Tr', 'Dist.', 'Sf.', 'Race', 'Cnd', '1st', '2nd', '3rd', 'Time']
#df = df.drop(columns=[col for col in df if col not in headers])

#new = [x for x in master if x not in ped]
final = []
[final.append(x) for x in master if x not in final]

floats = list()
for i in final:
    if type(i) is float:
        floats.append(i)

cleaned = [x for x in final if str(x) != 'nan']
len(cleaned)
# Out:
# 16745

# %%
for i in range(0,len(cleaned)):
    cleaned[i] = cleaned[i].replace(' ', '_')
cleaned
# Out:
# ['Nannerl',
#  'Note_to_Mimi',
#  'Parkdale',
#  'Party_Ribbon',
#  'Pearlwood',
#  'Pheroz_Fantasy_(NZ)',
#  'Pretty_Indian',
#  'Princess_Caveat',
#  'Private_Fun',
#  'Private_Prom_Party',
#  'Really_Quick',
#  'Rebridled_Secret',
#  'Red_Cause',
#  'Retroesque',
#  'Rickey_Raja',
#  'Road_to_Honor',
#  'Royal_Navy',
#  'Salty_Lady',
#  'Secret_Partner',
#  'Shannons_Debut',
#  'Sharp_Country',
#  'Sharp_n_Strong',
#  'Singing_in_the_Sun',
#  'Sky_Ruckus',
#  'Sofisticada',
#  'Southern_Serenity',
#  'Star_of_My_Eye',
#  'Stormy_Dynasty',
#  "Sue's_Temper",
#  'Summit_Lite',
#  'Super_Deelites',
#  'Swift_Girl',
#  'Tchopitioulas',
#  "That's_My_Hon",
#  'Time_for_Jazz',
#  'Timely_Broad',
#  'Toasttofriendship',
#  'Tropez',
#  'U_K_Trick',
#  'Unbridled_Fantasy_(AUS)',
#  'Unbridled_Queen',
#  'Valid_Bonnet',
#  'Vennila_Appeal',
#  'Very_Special_Lite',
#  'Victorious_Gal',
#  "Wait_'til_Midnight",
#  'Wanna_Kat',
#  'Wildcard_Cat',
#  'Wild_Libby',
#  'Aleutian_Gold',
# ...

# %%
# head = ['S','SS','SSS','SSD','SD','SDS','SDD','D','DS','DSS','DSD','DD','DDS','DDD']
# cl = cleaned[0:2]
# dt = pd.DataFrame(columns=head)
# dt['Name'] = cl
# first = dt.pop('Name')
# dt.insert(0,'Name',first)
# dt
dt.shape
# Out:
# (2, 15)

# %%
from selenium.webdriver.chrome.options import Options

path_to_extension = r'C:\Users\Jeanne\Documents\personal\Auction Results\3.10.2_0'

chrome_options = Options()
chrome_options.add_argument('load-extension=' + path_to_extension)

driver = webdriver.Chrome(chrome_options=chrome_options)
driver.create_options()

head = ['Name','S','SS','SSS','SSD','SD','SDS','SDD','D','DS','DSS','DSD','DD','DDS','DDD']
#dt = pd.DataFrame(columns=head)
#first = dt.pop('Name')
#dt.insert(0,'Name',first)

tempdelete = list()
tempdelete.append('By_My_Standards')
for i in tempdelete:
#for i in cleaned:
    hname = i
    url = 'https://www.horseracingnation.com/horse/' + hname
    driver.get(url)
    
    r = list()

    r.append(hname)
    z = driver.find_elements_by_xpath('//td[@id="1-1"]')
    if (len(z) == 1):
        r.append(driver.find_elements_by_xpath('//td[@id="1-1"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="1-2"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="1-3"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="2-3"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="3-2"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="3-3"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="4-3"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="5-1"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="5-2"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="5-3"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="6-3"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="7-2"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="7-3"]')[0].text)
        r.append(driver.find_elements_by_xpath('//td[@id="8-3"]')[0].text)
    else:
        for a in range(14):
            r.append(np.nan)    
    
    to_append = r
    dt_length = len(dt)
    dt.loc[dt_length] = to_append

#     # locate tr
#     tablerow = driver.find_elements_by_xpath('//tr[@class="dxgvDataRow "]')
#     for row in tablerow:
#     # tdata = [td.text for td in row.find_elements_by_class_name('dxgv')]
#       tdata = [td.text for td in row.find_elements_by_xpath('//td[@class="dxgv"]')]

#     x = int(len(tdata) / 12)
#     temp = pd.DataFrame(np.array(tdata).reshape(x,12), columns = headers)
#     df = df.append(temp) # appends to master dataframe
    
driver.close()
    
dt.to_csv(r'C:\Users\Jeanne\Documents\personal\Auction Results\pedigree.csv')
dt.shape
# Out:
# <ipython-input-74-d91f874bc72e>:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
# (16746, 15)

# %%
head = ['Name','S','SS','SSS','SSD','SD','SDS','SDD','D','DS','DSS','DSD','DD','DDS','DDD']
dt = dt.drop(columns=[col for col in dt if col not in head])

# %%
dt.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          Name              S               SS  \
# 0           0             0       Nannerl   Valid Appeal       In Reality
# 1           1             1  Note_to_Mimi       Notebook   Well Decorated
# 2           2             2      Parkdale  no data found    no data found
# 3           3             3  Party_Ribbon      Java Gold  Key to the Mint
# 4           4             4     Pearlwood  no data found    no data found
#
#              SSS            SSD             SD            SDS             SDD  \
# 0  Intentionally   My Dear Girl   Desert Trial   Moslem Chief  Scotch Verdict
# 1      Raja Baba   Paris Breeze         Mobcap      Tom Rolfe   Cap and Bells
# 2  no data found  no data found  no data found  no data found   no data found
# 3      Graustark     Key Bridge       Javamine    Nijinsky II   Dusky Evening
# 4  no data found  no data found  no data found  no data found   no data found
#
# ...

# %%
dt.shape
# Out:
# (16745, 15)

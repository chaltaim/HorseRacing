# %%
#pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup
import math

# %%
sr = pd.read_csv("/Users/Jeanne/Documents/personal/Auction Results/soldresults10yr.csv")
prog = pd.read_csv(r'C:\Users\Jeanne\Documents\personal\Auction Results\proglist.csv')

# %%
master = list(sr['Damf'])
master.extend(list(sr['Siref']))
#master.extend(list(sr['DS']))
proglist = list(prog['Name'])

#df = ped
#headers = ['Date', 'Horse', 'Fin', 'Tr', 'Dist.', 'Sf.', 'Race', 'Cnd', '1st', '2nd', '3rd', 'Time']
#df = df.drop(columns=[col for col in df if col not in headers])

new = [x for x in master if x not in proglist]
final = []
[final.append(x) for x in new if x not in final]

floats = list()
for i in final:
    if type(i) is float:
        floats.append(i)

cleaned = [x for x in final if str(x) != 'nan']
len(cleaned)
# Out:
# 1081

# %%
for i in range(0,len(cleaned)):
    cleaned[i] = cleaned[i].replace(' ', '_')
cleaned
# Out:
# ['Time_to_Be_Great',
#  'Empire_Maker',
#  'Belgravia',
#  'Salt_Lake',
#  'General_Meeting',
#  'Flower_Alley',
#  'Cartwright',
#  'Olmodavor',
#  'Adhocracy',
#  'Spanish_Steps',
#  'Good_and_Tough',
#  'Showing_Up',
#  'Birdstone',
#  'Grace_of_Darby',
#  'Mutakddim',
#  'Summer_Squall',
#  'Paynes_Bay',
#  'Suave',
#  'Smart_Strike',
#  'Salute_the_Sarge',
#  'Archers_Bay',
#  'Formal_Dinner',
#  'Crafty_Prospector',
#  'Hennessy',
#  'Crusader_Sword',
#  'Lemon_Drop_Kid',
#  'Master_Command',
#  'Roman_Ruler',
#  'Bwana_Charlie',
#  'Deputy_Commander',
#  'Forest_Camp',
#  'Aldebaran',
#  'Ghazi',
#  'Sweetsouthernsaint',
#  'Afternoon_Deelites',
#  'Eskimo',
#  'Flashy_Bull',
#  'Circular_Quay',
#  'Skip_Trial',
#  'Smarty_Jones',
#  'Woodman',
#  'Runaway_Groom',
#  'Skip_Away',
#  'Desert_Warrior',
#  'Eddington',
#  'Alke',
#  'Cure_the_Blues',
#  'Forestry',
#  'Tale_of_the_Cat',
#  'Wild_Desert',
#  'Got_the_Last_Laugh',
#  'High_Cotton',
#  'Malibu_Moon',
# ...

# %%
head = ('Name','Progeny_raw')
dx = pd.DataFrame(columns=head)
dx
# Out:
# Empty DataFrame
# Columns: [Name, Progeny_raw]
# Index: []

# %%
from selenium.webdriver.chrome.options import Options

path_to_extension = r'C:\Users\Jeanne\Documents\personal\Auction Results\3.10.2_0'

chrome_options = Options()
chrome_options.add_argument('load-extension=' + path_to_extension)

driver = webdriver.Chrome(chrome_options=chrome_options)
driver.create_options()
    
url = 'https://www.horseracingnation.com/horse/A_Jealous_Woman_progeny'
driver.get(url)

r = driver.find_elements_by_xpath('//td[@class="dxdvCtrl"]')[0].text

#for i in range(10):
#    tablecol = driver.find_elements_by_xpath('//td[@id="ct100_MainContent_uxHorsProgeny_uxProgenyList_ICell"]')
#    for col in tablecol:
#        dat = col.find_elements_by_xpath('//tr['+str(i)+']')]
#        # tdata = [td.text for td in row.find_elements_by_class_name('dxgv')]
#        tdata = [tr.text for tr in col.find_elements_by_xpath('//tr['+str(i)+']')]
            
driver.close()

r
# Out:
# <ipython-input-77-87f38422955e>:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
# 'By My Standards (USA)\nGentle Soul (USA)\nRedemption Time (USA)\n   '

# %%
#df = pd.DataFrame(columns=headers) # creates master dataframe 

from selenium.webdriver.chrome.options import Options

path_to_extension = r'C:\Users\Jeanne\Documents\personal\Auction Results\3.10.2_0'

chrome_options = Options()
chrome_options.add_argument('load-extension=' + path_to_extension)

driver = webdriver.Chrome(chrome_options=chrome_options)
driver.create_options()

#driver = webdriver.Chrome('/Users/Jeanne/Downloads/chromedriver')

for i in cleaned:
    hname = i
    url = 'https://www.horseracingnation.com/horse/' + hname + '_progeny'
    driver.get(url)

    row = list()
    row.append(hname.replace('_',' '))
    z = driver.find_elements_by_xpath('//td[@class="dxdvCtrl"]')
    if (len(z) == 1):
        a = driver.find_elements_by_xpath('//td[@class="dxdvCtrl"]')[0].text
        row.append(a)
                
    else:
        row.append(np.nan)

    to_append = row
    dx_length = len(dx)
    dx.loc[dx_length] = to_append
        
    recall = dx    
    
driver.close()
    
dx.to_csv(r'C:\Users\Jeanne\Documents\personal\Auction Results\proglist.csv')
# Out:
# <ipython-input-70-f20ed2bf7f23>:10: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)

# %%
dx.shape
# Out:
# (18813, 2)

# %%
dx.head
# Out:
# <bound method NDFrame.head of                      Name                                        Progeny_raw
# 0                 Nannerl  [<selenium.webdriver.remote.webelement.WebElem...
# 1            Note to Mimi  [<selenium.webdriver.remote.webelement.WebElem...
# 2                Parkdale  [<selenium.webdriver.remote.webelement.WebElem...
# 3            Party Ribbon  [<selenium.webdriver.remote.webelement.WebElem...
# 4               Pearlwood  [<selenium.webdriver.remote.webelement.WebElem...
# ...                   ...                                                ...
# 32217  Any Given Saturday  Page 1 of 6\nHoppertunity (USA)\nMongolian Sat...
# 32218              Tejano  Tejano Run (USA)\nAkiba (USA)\nBountiful V (US...
# 32219           Montbrook  Page 1 of 6\nAmen Hallelujah (USA)\nBig Drama ...
# 32220          Scat Daddy  Page 1 of 13\nDaddys Lil Darling (USA)\nLady o...
# 32221    Coronado's Quest                                                NaN
#
# ...

# %%
recall = dx

# %%
dx = dx[~dx['Progeny_raw'].astype(str).str.contains("selenium", na=False)]

# %%
dx.shape
# Out:
# (18813, 2)

# %%
dx.head
# Out:
# <bound method NDFrame.head of                       Name                                        Progeny_raw
# 5      Pheroz Fantasy (NZ)                                                NaN
# 11        Rebridled Secret                                                NaN
# 19          Shannons Debut                                                NaN
# 27          Stormy Dynasty                                                NaN
# 28            Sue's Temper                                                NaN
# ...                    ...                                                ...
# 32217   Any Given Saturday  Page 1 of 6\nHoppertunity (USA)\nMongolian Sat...
# 32218               Tejano  Tejano Run (USA)\nAkiba (USA)\nBountiful V (US...
# 32219            Montbrook  Page 1 of 6\nAmen Hallelujah (USA)\nBig Drama ...
# 32220           Scat Daddy  Page 1 of 13\nDaddys Lil Darling (USA)\nLady o...
# 32221     Coronado's Quest                                                NaN
#
# ...

# %%
dx.shape
# Out:
# (32222, 2)

# %%
dx.to_csv(r'C:\Users\Jeanne\Documents\personal\Auction Results\proglist.csv')

# %%
recall.shape
# Out:
# (18813, 2)

# %%
row = list()
row.append('A Jealous Woman')
row.append(r)
    
to_append = row
dx_length = len(dx)
dx.loc[dx_length] = to_append

# %%
dx[dx['Name'] == 'A Jealous Woman']
# Out:
#                   Name                                        Progeny_raw
# 18813  A Jealous Woman  By My Standards (USA)\nGentle Soul (USA)\nRede...
# 30709  A Jealous Woman  By My Standards (USA)\nGentle Soul (USA)\nRede...

# %%
dx.shape
# Out:
# (18813, 2)

# %%
dx.to_csv(r'C:\Users\Jeanne\Documents\personal\Auction Results\proglist.csv')
